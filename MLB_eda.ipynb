# %% [markdown]
# # MLB exploratory data analysis (EDA)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('MLB_height_weight.csv')
df
# Out:
#                  Name Team        Position  Height(inches)  Weight(pounds)  \
# 0       Adam_Donachie  BAL         Catcher              74           180.0
# 1           Paul_Bako  BAL         Catcher              74           215.0
# 2     Ramon_Hernandez  BAL         Catcher              72           210.0
# 3        Kevin_Millar  BAL   First_Baseman              72           210.0
# 4         Chris_Gomez  BAL   First_Baseman              73           188.0
# ...               ...  ...             ...             ...             ...
# 1029    Brad_Thompson  STL  Relief_Pitcher              73           190.0
# 1030    Tyler_Johnson  STL  Relief_Pitcher              74           180.0
# 1031   Chris_Narveson  STL  Relief_Pitcher              75           205.0
# 1032    Randy_Keisler  STL  Relief_Pitcher              75           190.0
# 1033      Josh_Kinney  STL  Relief_Pitcher              73           195.0
#
#         Age
# 0     22.99
# 1     34.69
# 2     30.78
# 3     35.43
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                  Name Team        Position  Height(inches)  Weight(pounds)  \
# 0       Adam_Donachie  BAL         Catcher              74           180.0
# 1           Paul_Bako  BAL         Catcher              74           215.0
# 2     Ramon_Hernandez  BAL         Catcher              72           210.0
# 3        Kevin_Millar  BAL   First_Baseman              72           210.0
# 4         Chris_Gomez  BAL   First_Baseman              73           188.0
# ...               ...  ...             ...             ...             ...
# 1029    Brad_Thompson  STL  Relief_Pitcher              73           190.0
# 1030    Tyler_Johnson  STL  Relief_Pitcher              74           180.0
# 1031   Chris_Narveson  STL  Relief_Pitcher              75           205.0
# 1032    Randy_Keisler  STL  Relief_Pitcher              75           190.0
# 1033      Josh_Kinney  STL  Relief_Pitcher              73           195.0
#
#         Age
# 0     22.99
# 1     34.69
# 2     30.78
# 3     35.43
# ...

# %%
df['Position'].unique()
# Out:
# array(['Catcher', 'First_Baseman', 'Second_Baseman', 'Shortstop',
#        'Third_Baseman', 'Outfielder', 'Designated_Hitter',
#        'Starting_Pitcher', 'Relief_Pitcher'], dtype=object)

# %%
pos = df.groupby('Position')

# %%
np.polyfit(df['Height(inches)'], df['Weight(pounds)'],1)
# Out:
# array([   4.841, -155.092])

# %%
# %matplotlib notebook

xpts = np.linspace(66,84)

for n, gp in pos:
    x, y = gp['Height(inches)'].values, gp['Weight(pounds)'].values
    plt.plot(x,y, 'k.', alpha=0.1)
    p = np.polyfit(x,y,1)
    plt.plot(xpts, p[0]*xpts + p[1],'-',label=n)
    
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
